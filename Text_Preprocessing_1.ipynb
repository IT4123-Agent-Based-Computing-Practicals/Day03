# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download necessary NLTK resources (run only onece)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Example test
text = "The quick brown fox jumps over the lazy dog! Isn't it amazing?"

print("Original Text:", text)

# Lowercasing
text = text.lower()

print("\nAfter Lowercasing:", text)

# Remove Punctuation & Special Characters
text = text.translate(str.maketrans('','',string.punctuation))
print("\nAfter Removing Punctuation:", text)

# Tokenization
tokens = word_tokenize(text)
print("\nAfter Tokenization:", tokens)

# Remove Stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print("\nAfter Removing Stopwords:", filtered_tokens)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# Original Text: The quick brown fox jumps over the lazy dog! Isn't it amazing?
#
# After Lowercasing: the quick brown fox jumps over the lazy dog! isn't it amazing?
#
# After Removing Punctuation: the quick brown fox jumps over the lazy dog isnt it amazing
#
# After Tokenization: ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', 'isnt', 'it', 'amazing']
#
# After Removing Stopwords: ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'isnt', 'amazing']
# [nltk_data]   Package omw-1.4 is already up-to-date!
