# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download necessary NLTK resources (run only once)
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords') 
nltk.download('wordnet')
nltk.download('omw-1.4')

# Example test
text = "Hello! This is an Example showing, how text Pre-processing works better."

print("Original Text:", text)

# Lowercasing
text = text.lower()

print("\nAfter Lowercasing:", text)

# Remove punctuation and special characters
text = text.translate(str.maketrans('', '', string.punctuation))
print("\nAfter Removing Punctuation:", text)

# Tokenization
tokens = word_tokenize(text)
print("\nAfter Tokenization:", tokens)

# Remove stop words
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
print("\nAfter Removing Stop Words:", filtered_tokens)

# Stremming
stremmer = PorterStemmer()
stremmed_words = [stremmer.stem(word) for word in filtered_tokens]
print("\nAfter Stemming:", stremmed_words)

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("\nAfter Lemmatization:", lemmatized_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Maduranga\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Original Text: Hello! This is an Example showing, how text Pre-processing works better.
#
# After Lowercasing: hello! this is an example showing, how text pre-processing works better.
#
# After Removing Punctuation: hello this is an example showing how text preprocessing works better
#
# After Tokenization: ['hello', 'this', 'is', 'an', 'example', 'showing', 'how', 'text', 'preprocessing', 'works', 'better']
#
# After Removing Stop Words: ['hello', 'example', 'showing', 'text', 'preprocessing', 'works', 'better']
#
# After Stemming: ['hello', 'exampl', 'show', 'text', 'preprocess', 'work', 'better']
#
# After Lemmatization: ['hello', 'example', 'showing', 'text', 'preprocessing', 'work', 'better']
